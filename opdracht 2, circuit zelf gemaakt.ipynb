# %%
import numpy as np
import sympy as sp
import matplotlib.pyplot as plt
import pandas as pd
from scipy.optimize import minimize, fsolve

# %%
#De data, intensiteit I(a.u.) en afstand x(mm) wordt eerst ingeladen.
#De pandas library bevat eenvoudige commando's om data in te lezen.

import pandas as pd

#De data is een text bestand, waarbij de kolommen gescheiden zijn door zelf ingevoerde tabs.
Data = pd.read_csv('data_opdracht_2_zelf_gemaakt.txt', sep="\t", header = 0)
display(Data)

Data.columns = ["a", "b", "c"]
f = Data.a
A = Data.b
phi = Data.c*np.pi/180
# Out:
#            Freq.  Amplitude   Fasehoek
# 0       1.000000  -4.053514  86.404726
# 1       1.023293  -3.854319  86.321209
# 2       1.047129  -3.655161  86.235762
# 3       1.071519  -3.456044  86.148343
# 4       1.096478  -3.256967  86.058906
# 5       1.122018  -3.057934  85.967405
# 6       1.148154  -2.858946  85.873795
# 7       1.174898  -2.660005  85.778027
# 8       1.202264  -2.461115  85.680053
# 9       1.230269  -2.262276  85.579822
# 10      1.258925  -2.063491  85.477286
# 11      1.288250  -1.864764  85.372390
# 12      1.318257  -1.666096  85.265084
# 13      1.348963  -1.467490  85.155313
# 14      1.380384  -1.268950  85.043021
# 15      1.412538  -1.070478  84.928154
# 16      1.445440  -0.872077  84.810653
# 17      1.479108  -0.673751  84.690461
# 18      1.513561  -0.475504  84.567517
# 19      1.548817  -0.277338  84.441762
# 20      1.584893  -0.079257  84.313133
# 21      1.621810   0.118733  84.181567
# 22      1.659587   0.316630  84.047001
# 23      1.698244   0.514429  83.909368
# 24      1.737801   0.712126  83.768603
# 25      1.778279   0.909715  83.624637
# 26      1.819701   1.107192  83.477401
# 27      1.862087   1.304552  83.326825
# 28      1.905461   1.501789  83.172837
# 29      1.949845   1.698897  83.015365
# ..           ...        ...        ...
# 271   512.861384  19.995820   1.777475
# 272   524.807460  19.996008   1.737039
# 273   537.031796  19.996187   1.697523
# 274   549.540874  19.996359   1.658904
# 275   562.341325  19.996523   1.621164
# 276   575.439937  19.996679   1.584280
# 277   588.843655  19.996828   1.548236
# 278   602.559586  19.996971   1.513010
# 279   616.595002  19.997107   1.478585
# 280   630.957344  19.997238   1.444943
# 281   645.654229  19.997362   1.412065
# 282   660.693448  19.997481   1.379935
# 283   676.082975  19.997594   1.348536
# 284   691.830971  19.997702   1.317851
# 285   707.945784  19.997806   1.287863
# 286   724.435960  19.997904   1.258557
# 287   741.310241  19.997999   1.229918
# 288   758.577575  19.998089   1.201930
# 289   776.247117  19.998175   1.174578
# 290   794.328235  19.998257   1.147849
# 291   812.830516  19.998335   1.121727
# 292   831.763771  19.998410   1.096200
# 293   851.138038  19.998482   1.071253
# 294   870.963590  19.998550   1.046874
# 295   891.250938  19.998615   1.023049
# 296   912.010839  19.998678   0.999767
# 297   933.254301  19.998737   0.977014
# 298   954.992586  19.998794   0.954778
# 299   977.237221  19.998848   0.933049
# 300  1000.000000  19.998900   0.911814
#
# [301 rows x 3 columns]

# %%
R = 1000
C = 10*10**(-6)

# %%
# Amplitude

# %%
#Vervolgens wordt er een plot gemaakt van de data. Dit geeft meer inzicht dan de tabellen met waarden in.

fig, ax = plt.subplots(nrows=1, ncols=1, dpi=150, figsize=(7, 4))


ax.set_title('Initiële plot van de data van de amplitude A in functie van de frequentie f')
ax.grid(True, which = 'both') #Voegt rijen en kolommen toe, zodat de datapunten beter vergeleken en afgelezen kunnen worden.
plt.errorbar(f, A, label = 'A(f)', fmt = 'd ', c='y', capsize=3, elinewidth=0.5, capthick=0.5)
plt.ylabel('$A$ [dB]', size=10)
plt.xlabel('$f$ $[Hz]$', size=10)
plt.legend(fontsize=14)
ax.set_xscale('log')
plt.tick_params(axis='both', which='major', labelsize=10)


plt.show()

# %%
tau = R*C
f_cut = 1/(2*np.pi*R*C)

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, dpi=150, figsize=(8, 3))

#We willen nu een goede benadering vinden van de gevonden data via een Lorentzfunctie die wordt gedefiniëerd als


def amplitude(f,tau):
    return tau*2*np.pi*abs(f)/np.sqrt(1+4*np.pi**2 * tau**2 * f**2)



#Vervolgens wordt er een initiële fit gemaakt van de data door waarden voor de parameters te gokken, 
#zodat de fit goed past op de data. 
#Na enig puzzelwerk, werden de volgende waarden voor de paramters gekozen die een goede fit lijken te bekomen:

def plot(ax, x, y):
    """Plotten functie Amplitude"""
    ax.plot(x, y, color = 'blue', linewidth=2, label = 'Fit')

tau = R * C

begin = [tau]

z = np.linspace(start=-10, stop= 1000, num=5000)

plt.errorbar(f, A/20, label = 'A(f)', fmt = 'd ', c='y', capsize=3, elinewidth=0.5, capthick=0.5)

plot(ax, z, amplitude(z,begin[0]))
ax.grid(True, which = 'both')



ax.set_title('Fit van de amplitude A in functie van de frequentie f')
ax.grid(True, which = 'both') #Voegt rijen en kolommen toe, zodat de datapunten beter vergeleken en afgelezen kunnen worden.
plt.ylabel('$A$ [dB]', size=10)
plt.xlabel('f $[Hz]$', size=10)
plt.legend(fontsize=14)
plt.axvline(x= f_cut)
plt.tick_params(axis='both', which='major', labelsize=10)
ax.set_xscale('log')



plt.show()

# %%
tau * 2 * np.pi * f_cut/np.sqrt(1+ 4*np.pi**2*tau**2*f_cut**2)
# Out:
# 0.7071067811865475

# %%
# Fasehoek

# %%
#Vervolgens wordt er een plot gemaakt van de data. Dit geeft meer inzicht dan de tabellen met waarden in.

fig, ax = plt.subplots(nrows=1, ncols=1, dpi=150, figsize=(7, 3))


ax.set_title('Initiële plot van de data voor de amplitude A in functie van de tijd t')
ax.grid(True, which = 'both') #Voegt rijen en kolommen toe, zodat de datapunten beter vergeleken en afgelezen kunnen worden.
plt.errorbar(f, phi, label = '$\phi$(f)', fmt = 'd ', c='y', capsize=3, elinewidth=0.5, capthick=0.5)
plt.ylabel('$\phi$ [°]', size=10)
plt.xlabel('$f$ $[Hz]$', size=10)
plt.legend(fontsize=14)
plt.tick_params(axis='both', which='major', labelsize=10)
ax.set_xscale('log')



plt.show()

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, dpi=150, figsize=(9, 4))

#We willen nu een goede benadering vinden van de gevonden data via een Lorentzfunctie die wordt gedefiniëerd als

def fasehoek(f, tau):
    return np.arctan2(1,tau*2*np.pi*f)



#Vervolgens wordt er een initiële fit gemaakt van de data door waarden voor de parameters te gokken, 
#zodat de fit goed past op de data. 
#Na enig puzzelwerk, werden de volgende waarden voor de paramters gekozen die een goede fit lijken te bekomen:

def plot(ax, x, y):
    """Plotten functie Amplitude"""
    ax.plot(x, y, color = 'blue', linewidth=10, label = 'Fit')

tau = R * C

begin = [tau]

z = np.linspace(start=1, stop= 1000, num=5000)

plt.errorbar(f, phi, label = 'V(t)', fmt = 'd ', c='y', capsize=3, elinewidth=0.5, capthick=0.5)

plot(ax, z, fasehoek(z,begin[0]))
ax.grid(True, which = 'both')



ax.set_title('Fit van de Fasehoek $\phi$ in functie van de frequentie f')
ax.grid(True, which = 'both') #Voegt rijen en kolommen toe, zodat de datapunten beter vergeleken en afgelezen kunnen worden.
plt.ylabel('$V$ [V]', size=10)
plt.xlabel('t $[s]$', size=10)
plt.legend(fontsize=14)
plt.tick_params(axis='both', which='major', labelsize=10)
ax.set_xscale('log')



plt.show()
